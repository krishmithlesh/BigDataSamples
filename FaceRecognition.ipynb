# %% [markdown]
# <a href="https://colab.research.google.com/github/krishmithlesh/BigDataSamples/blob/master/FaceRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyDrive
# Out:
# ...
#      |████████████████████████████████| 993kB 2.8MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# ...

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '1etNcpN4m4K8ecSUamRrzAlIo2zZ8TCn2'})

# %%
download.GetContentFile('DOWNLOAD.zip')

# %%
# !unzip DOWNLOAD.zip
# Out:
# Archive:  DOWNLOAD.zip
#    creating: pi-face-recognitionFinal/
#    creating: pi-face-recognitionFinal/pi-face-recognition/
#   inflating: pi-face-recognitionFinal/pi-face-recognition/encode_faces.py
#   inflating: pi-face-recognitionFinal/pi-face-recognition/pi_face_recognition.py
#   inflating: pi-face-recognitionFinal/pi-face-recognition/encodings.pickle
#    creating: pi-face-recognitionFinal/pi-face-recognition/dataset/
#    creating: pi-face-recognitionFinal/pi-face-recognition/dataset/Mahima Katiyar/
#   inflating: pi-face-recognitionFinal/pi-face-recognition/dataset/Mahima Katiyar/DSC_0257.JPG
#   inflating: pi-face-recognitionFinal/pi-face-recognition/dataset/Mahima Katiyar/DSC_0256.JPG
#   inflating: pi-face-recognitionFinal/pi-face-recognition/dataset/Mahima Katiyar/DSC_0255.JPG
#   inflating: pi-face-recognitionFinal/pi-face-recognition/dataset/Mahima Katiyar/DSC_0258.JPG
#   inflating: pi-face-recognitionFinal/pi-face-recognition/dataset/Mahima Katiyar/_DS_Store
# ...

# %%
cd pi-face-recognitionFinal/pi-face-recognition/
# Out:
# /content/pi-face-recognitionFinal/pi-face-recognition

# %%
pip install dlib

# %%
pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 254kB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
pip install imutils

# %%
# !python3 encode_faces.py --dataset dataset --encodings encodings.pickle --detection-method cnn
# Out:
# [INFO] quantifying faces...
# [INFO] processing image 1/315
# [INFO] processing image 2/315
# [INFO] processing image 3/315
# [INFO] processing image 4/315
# Corrupt JPEG data: premature end of data segment
# [INFO] processing image 5/315
# [INFO] processing image 6/315
# [INFO] processing image 7/315
# [INFO] processing image 8/315
# [INFO] processing image 9/315
# [INFO] processing image 10/315
# [INFO] processing image 11/315
# [INFO] processing image 12/315
# [INFO] processing image 13/315
# [INFO] processing image 14/315
# [INFO] processing image 15/315
# [INFO] processing image 16/315
# [INFO] processing image 17/315
# [INFO] processing image 18/315
# [INFO] processing image 19/315
# [INFO] processing image 20/315
# [INFO] processing image 21/315
# [INFO] processing image 22/315
# [INFO] processing image 23/315
# [INFO] processing image 24/315
# [INFO] processing image 25/315
# [INFO] processing image 26/315
# [INFO] processing image 27/315
# [INFO] processing image 28/315
# ...
